# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Jupyter Notebook Keyboard Shortcuts
#
# 1. Esc + M - Converts cell into a markdown cell (text, notes)
#
# 2. Esc + Y - Converts a cell into a code cell
#
# 3. Esc + A - Adds a cell above the current cell
#
# 4. Esc + B - Adds a cell below the current cell
#
# 5. Esc + DD - Deletes the selected/current cell
#
# 6. Shift + Enter - Runs the current cell CtrlEnter)
#
# 7. *yourtext* - Italicize the text
#
# 8. **yourtexthere** - **Bolds** the text

# %%
df = pd.read_csv('Diwali Sales Data.csv', encoding= 'unicode_escape')
# imported the csv files using the pandas dataframe and readCSV

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# 1  Andhraï¿½Pradesh  Southern             Govt             Auto       3
# 2     Uttar Pradesh   Central       Automobile             Auto       3
# 3         Karnataka  Southern     Construction             Auto       2
# 4           Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.shape
# Out:
# (11251, 15)

# %%
df['Occupation'].value_counts()
# Out:
# Occupation
# IT Sector          1588
# Healthcare         1408
# Aviation           1310
# Banking            1139
# Govt                854
# Hospitality         705
# Media               637
# Automobile          566
# Chemical            542
# Lawyer              531
# Retail              501
# Food Processing     423
# Construction        414
# Textile             350
# Agriculture         283
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# 1  Andhraï¿½Pradesh  Southern             Govt             Auto       3
# 2     Uttar Pradesh   Central       Automobile             Auto       3
# 3         Karnataka  Southern     Construction             Auto       2
# 4           Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
df.head(8)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
# 5  1000588       Joni  P00057942      M     26-35   28               1
# 6  1001132       Balk  P00018042      F     18-25   25               1
# 7  1002092   Shivangi  P00273442      F       55+   61               0
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# 1  Andhraï¿½Pradesh  Southern             Govt             Auto       3
# 2     Uttar Pradesh   Central       Automobile             Auto       3
# ...

# %%
#drop unrelated columns that doesnt have any meaning
df.drop(['Status', 'unnamed1'], axis=1, inplace=True)
# axis=1 means i wanna drop the column
# axis=0 means i wanna drop the rows not the column values
# here the code shows error as i have already dropped now

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df['Product_ID'] = df['Product_ID'].str.lstrip('P')

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti   00125942      F     26-35   28               0
# 1  1000732     Kartik   00110942      F     26-35   35               1
# 2  1001990      Bindu   00118542      F     26-35   35               1
# 3  1001425     Sudevi   00237842      M      0-17   16               0
# 4  1000588       Joni   00057942      M     26-35   28               1
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# 1  Andhraï¿½Pradesh  Southern             Govt             Auto       3
# 2     Uttar Pradesh   Central       Automobile             Auto       3
# 3         Karnataka  Southern     Construction             Auto       2
# 4           Gujarat   Western  Food Processing             Auto       2
#
#     Amount
# 0  23952.0
# 1  23934.0
# 2  23924.0
# 3  23912.0
# 4  23877.0

# %%
df.isnull().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df.info()
# to check the null values in the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
df.shape
# Out:
# (11251, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
#check for null values
pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
# drop null values from the given dataframe
df.dropna(inplace=True)
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti   00125942      F     26-35   28               0
# 1      1000732       Kartik   00110942      F     26-35   35               1
# 2      1001990        Bindu   00118542      F     26-35   35               1
# 3      1001425       Sudevi   00237842      M      0-17   16               0
# 4      1000588         Joni   00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning   00296942      M     18-25   19               1
# 11247  1004089  Reichenbach   00171342      M     26-35   33               0
# 11248  1001209        Oshin   00201342      F     36-45   40               0
# 11249  1004023       Noonan   00059442      M     36-45   37               0
# 11250  1002744      Brumley   00281742      F     18-25   19               0
#
# ...

# %%
df['Marital_Status'].value_counts()
# Out:
# Marital_Status
# 0    6518
# 1    4721
# Name: count, dtype: int64

# %%
# Changing the marital status of the people from the dataframe from numeric to string ie \
# 0-> unmarried and 1-> married hence changing it 

df['Marital_Status'] = df['Marital_Status'].replace({0:'Unmarried',1:'Married'})
df['Marital_Status']
# Out:
# 0        Unmarried
# 1          Married
# 2          Married
# 3        Unmarried
# 4          Married
#            ...
# 11246      Married
# 11247    Unmarried
# 11248    Unmarried
# 11249    Unmarried
# 11250    Unmarried
# Name: Marital_Status, Length: 11239, dtype: object

# %%
pd.isnull(df).sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
df.dtypes
# Out:
# User_ID               int64
# Cust_name            object
# Product_ID           object
# Gender               object
# Age Group            object
# Age                   int64
# Marital_Status       object
# State                object
# Zone                 object
# Occupation           object
# Product_Category     object
# Orders                int64
# Amount              float64
# dtype: object

# %%
# Here the dtype of the product ID is object which is incorrect in our dataframe because 
# the product id of the various products cannot have letters in it so we only include 
# the numeric value for the product id in our datas

df['Product_ID'] = df['Product_ID'].astype(int)

# %%
df.dtypes
# Out:
# User_ID               int64
# Cust_name            object
# Product_ID            int64
# Gender               object
# Age Group            object
# Age                   int64
# Marital_Status       object
# State                object
# Zone                 object
# Occupation           object
# Product_Category     object
# Orders                int64
# Amount              float64
# dtype: object

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
pd.crosstab(df['Gender'], df['Occupation'])
# Out:
# Occupation  Agriculture  Automobile  Aviation  Banking  Chemical  \
# Gender
# F                   203         391       932      823       378
# M                    80         174       378      314       163
#
# Occupation  Construction  Food Processing  Govt  Healthcare  Hospitality  \
# Gender
# F                    300              295   605         968          468
# M                    114              128   249         440          235
#
# Occupation  IT Sector  Lawyer  Media  Retail  Textile
# Gender
# F                1071     364    428     370      236
# M                 512     167    209     131      113

# %%
# use describe() for specific columns
df[['Age', 'Orders', 'Amount']].describe()
# Here order refers to the various orders of the people in diwali according to their 
# various properties ( zone, state etc)
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.410357      2.489634   9453.610858
# std       12.753866      1.114967   5222.355869
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Gender

# %%
df.head()
# Out:
#    User_ID  Cust_name  Product_ID Gender Age Group  Age Marital_Status  \
# 0  1002903  Sanskriti      125942      F     26-35   28      Unmarried
# 1  1000732     Kartik      110942      F     26-35   35        Married
# 2  1001990      Bindu      118542      F     26-35   35        Married
# 3  1001425     Sudevi      237842      M      0-17   16      Unmarried
# 4  1000588       Joni       57942      M     26-35   28        Married
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# 1  Andhraï¿½Pradesh  Southern             Govt             Auto       3
# 2     Uttar Pradesh   Central       Automobile             Auto       3
# 3         Karnataka  Southern     Construction             Auto       2
# 4           Gujarat   Western  Food Processing             Auto       2
#
#     Amount
# 0  23952.0
# 1  23934.0
# 2  23924.0
# 3  23912.0
# 4  23877.0

# %%
df['Age'].corr(df['Orders'])
# Out:
# np.float64(0.008089851507349434)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# F    7832
# M    3407
# Name: count, dtype: int64

# %%
# plotting a bar chart for Gender and it's count
fig,ax = plt.subplots(figsize=(7,7))
ax = sns.countplot(x = 'Gender',data = df,
                   color='red',
                   edgecolor='black')
ax.set_xlabel("Gender of the people of the dataframe",
              color='red')
ax.set_ylabel("Total Count of the gender from the Dataframe",
              color='red')

for bars in ax.containers:
    ax.bar_label(bars)
    
# Hence this shows us that the number of male in our dataframe is quite large in number 
# than the number of female from the dataframe

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
df['Orders']
# Out:
# 0        1
# 1        3
# 2        3
# 3        2
# 4        2
#         ..
# 11246    4
# 11247    3
# 11248    4
# 11249    3
# 11250    3
# Name: Orders, Length: 11239, dtype: int64

# %%
df['Orders'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (11239, 13)

# %%
df['Orders'].value_counts().sum()
# Out:
# np.int64(11239)

# %%
# plotting a bar chart for gender vs total amount

sales_gen = df.groupby(['Gender'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False)

sns.barplot(x = 'Gender',y= 'Orders' ,data = sales_gen)
# Out:
# <Axes: xlabel='Gender', ylabel='Orders'>

# %% [markdown]
# * Hence we can conclude that the purchasing capacity and quantity of women is more than that of the male in general *

# %%
df.head()
# Out:
#    User_ID  Cust_name  Product_ID Gender Age Group  Age Marital_Status  \
# 0  1002903  Sanskriti      125942      F     26-35   28      Unmarried
# 1  1000732     Kartik      110942      F     26-35   35        Married
# 2  1001990      Bindu      118542      F     26-35   35        Married
# 3  1001425     Sudevi      237842      M      0-17   16      Unmarried
# 4  1000588       Joni       57942      M     26-35   28        Married
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# 1  Andhraï¿½Pradesh  Southern             Govt             Auto       3
# 2     Uttar Pradesh   Central       Automobile             Auto       3
# 3         Karnataka  Southern     Construction             Auto       2
# 4           Gujarat   Western  Food Processing             Auto       2
#
#     Amount     For_checks  For_Check
# 0  23952.0  (28, 23952.0)    23980.0
# ...

# %%
# Here we check the categorical columns relationship from our datasets
df[['Age', 'Amount']]
# Out:
#        Age   Amount
# 0       28  23952.0
# 1       35  23934.0
# 2       35  23924.0
# 3       16  23912.0
# 4       28  23877.0
# ...    ...      ...
# 11246   19    370.0
# 11247   33    367.0
# 11248   40    213.0
# 11249   37    206.0
# 11250   19    188.0
#
# [11239 rows x 2 columns]

# %%
import matplotlib.pyplot as plt 
# Creating a scatter plot of the given 2 columns ie the age column and the amount column

plt.scatter(df['Age'],df['Amount'], color='red')
plt.title("Scatter plotting of the datas")
plt.xlabel("Ages of the people")
plt.ylabel("Amount of money they have earned ")
plt.show()

# %%
# plotting a histogram from the given data 
plt.Figure(figsize=(50,50))
plt.hist2d(df['Age'], df['Amount'], bins=[10, 10], cmap='Blues')
plt.colorbar(label='Count')
plt.xlabel('Age')
plt.ylabel('Amount')
plt.show()

# %% [markdown]
# # So generally we can clearly see that the people aged below are more in number and are likely to earn more than the people aged over 50 years from the above scatter plots

# %%
plt.Figure(figsize=(15,15))
plt.plot(df['Age'],df['Amount'],marker='o')

# %% [markdown]
# ### Age

# %%
df.head()
# Out:
#    User_ID  Cust_name  Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti      125942      F     26-35   28               0
# 1  1000732     Kartik      110942      F     26-35   35               1
# 2  1001990      Bindu      118542      F     26-35   35               1
# 3  1001425     Sudevi      237842      M      0-17   16               0
# 4  1000588       Joni       57942      M     26-35   28               1
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# 1  Andhraï¿½Pradesh  Southern             Govt             Auto       3
# 2     Uttar Pradesh   Central       Automobile             Auto       3
# 3         Karnataka  Southern     Construction             Auto       2
# 4           Gujarat   Western  Food Processing             Auto       2
#
#     Amount
# 0  23952.0
# 1  23934.0
# 2  23924.0
# 3  23912.0
# 4  23877.0

# %%
ax = sns.countplot(data = df, x = 'Marital_Status', hue = 'Gender')
# Here hue generally comes with the column value for the relational representation with the colomnical value
for bars in ax.containers:
    ax.bar_label(bars)
    
# Here marital status for 0 represents or denotes unmarriaged and 1 -> marriaged

# %% [markdown]
# * Here by the above bi-graphs we can clearly see that the number of unmarried female is comparatively more than that of the married men *

# %%
df.groupby('Gender')['Marital_Status'].sum()
# Here the sum represents the total number of married female and male in the given datasets
# Out:
# Gender
# F    3259
# M    1462
# Name: Marital_Status, dtype: int64

# %%
df.groupby('Marital_Status')['Gender'].value_counts()
# Here 0 represents the unmarried size of the female and male whereas the 1 value represents the married amount or size of the male and female from the given dataframe of ours.
# Out:
# Marital_Status  Gender
# 0               F         4573
#                 M         1945
# 1               F         3259
#                 M         1462
# Name: count, dtype: int64

# %%
bx = sns.countplot(data = df, x="Age Group", hue="State", )

# %%
sales_age = df.groupby(['Age Group'], as_index=False)['Amount'].sum()
sales_age
# Out:
#   Age Group       Amount
# 0      0-17   2699653.00
# 1     18-25  17240732.00
# 2     26-35  42613443.94
# 3     36-45  22144995.49
# 4     46-50   9207844.00
# 5     51-55   8261477.00
# 6       55+   4080987.00

# %%
df.head(5)

df.head()
# Out:
#    User_ID  Cust_name  Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti      125942      F     26-35   28               0
# 1  1000732     Kartik      110942      F     26-35   35               1
# 2  1001990      Bindu      118542      F     26-35   35               1
# 3  1001425     Sudevi      237842      M      0-17   16               0
# 4  1000588       Joni       57942      M     26-35   28               1
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# 1  Andhraï¿½Pradesh  Southern             Govt             Auto       3
# 2     Uttar Pradesh   Central       Automobile             Auto       3
# 3         Karnataka  Southern     Construction             Auto       2
# 4           Gujarat   Western  Food Processing             Auto       2
#
#     Amount
# 0  23952.0
# 1  23934.0
# 2  23924.0
# 3  23912.0
# 4  23877.0

# %%
# Total Amount vs Age Group
sales_age = df.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x = 'Age Group', y = 'Amount' , data = sales_age)
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %% [markdown]
# *From the above graph it indicates that most of the buyers of the diwali products age ranges between 26-35*

# %% [markdown]
# ### State

# %%
# total number of orders from top 10 states

sales_state = df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'State',y= 'Orders')
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data= df, x="State", y="Orders")
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
# total amount/sales from top 10 states

sales_state = df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'State',y= 'Amount')
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %%
sns.barplot(data=df, x="State", y="Amount")
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the orders & total sales/amount are from Uttar Pradesh, Maharashtra and Karnataka respectively*

# %% [markdown]
# ### Marital Status

# %%
ax = sns.countplot(data = df, x = 'Marital_Status')

sns.set(rc={'figure.figsize':(7,5)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Marital_Status', 'Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(data = sales_state, x = 'Marital_Status',y= 'Amount', hue='Gender')
# 0 is for unmarried and 1 is for married people
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the buyers are married (women) and they have high purchasing power*

# %% [markdown]
# ### Occupation

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data = df, x = 'Occupation')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Occupation',y= 'Amount')
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the buyers are working in IT, Healthcare and Aviation sector*

# %% [markdown]
# ### Product Category

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data = df, x = 'Product_Category')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_Category',y= 'Amount')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the sold products are from Food, Clothing and Electronics category*
# Bishesh Pandey

# %%
sales_state = df.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_ID',y= 'Orders')
# Out:
# <Axes: xlabel='Product_ID', ylabel='Orders'>

# %%
# top 10 most sold products (same thing as above)

fig1, ax1 = plt.subplots(figsize=(12,7))
df.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>
